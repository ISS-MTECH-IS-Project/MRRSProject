# %%
# !pip install py2neo
# !pip install neomodel
# !pip install pandas
# Out:
# Collecting py2neo
#   Using cached py2neo-2021.2.3-py2.py3-none-any.whl (177 kB)
# Requirement already satisfied: pygments>=2.0.0 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from py2neo) (2.11.2)
# Collecting monotonic
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting interchange~=2021.0.4
#   Using cached interchange-2021.0.4-py2.py3-none-any.whl (28 kB)
# Collecting urllib3
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 5.5 MB/s eta 0:00:01
# Collecting pansi>=2020.7.3
#   Using cached pansi-2020.7.3-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from py2neo) (2021.10.8)
# Requirement already satisfied: six>=1.15.0 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: packaging in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from py2neo) (21.3)
# Collecting pytz
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 14.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from packaging->py2neo) (3.0.4)
# Installing collected packages: pytz, urllib3, pansi, monotonic, interchange, py2neo
# Successfully installed interchange-2021.0.4 monotonic-1.6 pansi-2020.7.3 py2neo-2021.2.3 pytz-2022.1 urllib3-1.26.9
# Collecting neomodel
#   Using cached neomodel-4.0.8-py3-none-any.whl (46 kB)
# Collecting Shapely==1.7.1
#   Downloading Shapely-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 4.6 MB/s eta 0:00:01
# Collecting neobolt==1.7.17
#   Using cached neobolt-1.7.17.tar.gz (183 kB)
# Collecting neo4j-driver==4.3.6
#   Using cached neo4j-driver-4.3.6.tar.gz (76 kB)
# Requirement already satisfied: pytz>=2021.1 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from neomodel) (2022.1)
# Requirement already satisfied: six==1.16.0 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from neomodel) (1.16.0)
# Building wheels for collected packages: neo4j-driver, neobolt
#   Building wheel for neo4j-driver (setup.py) ... done
#   Created wheel for neo4j-driver: filename=neo4j_driver-4.3.6-py3-none-any.whl size=100614 sha256=35243d23e9a690eb36e12d09223f43a0998f300de95c56da31967b633f87af7a
#   Stored in directory: /home/alan/.cache/pip/wheels/1e/e2/40/4186acdee3569834fac4f80fab5a1ff256523549628e15dc28
#   Building wheel for neobolt (setup.py) ... done
#   Created wheel for neobolt: filename=neobolt-1.7.17-cp37-cp37m-linux_x86_64.whl size=695225 sha256=e5cdec55f5ab8361b5ec105b1c4a6ab7569cdcb36f6be9367b8c07ea88a5006a
#   Stored in directory: /home/alan/.cache/pip/wheels/9d/46/80/bbc5e90b72fcad84080d47919dddb8c90437de148a8501b434
# Successfully built neo4j-driver neobolt
# Installing collected packages: Shapely, neobolt, neo4j-driver, neomodel
# Successfully installed Shapely-1.7.1 neo4j-driver-4.3.6 neobolt-1.7.17 neomodel-4.0.8
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 3.8 MB/s eta 0:00:01    |████████████▎                   | 4.3 MB 3.8 MB/s eta 0:00:02     |██████████████████▏             | 6.4 MB 3.8 MB/s eta 0:00:02
# Collecting numpy>=1.17.3
#   Using cached numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/alan/anaconda3/envs/oohfish-env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.5 pandas-1.3.5

# %%
from DataSetupPackage import DataSetUpPackage
from DataAccessLayer import DataAccessLayer
import json

# %%
dbcon = DataAccessLayer(username='neo4j',password='ai-user').CreateDBConnection
dbcon.ClearCurrentDB  # This will clean up the neo4jDB
DataSetUpPackage().ReadCSVAndPopulateDB.PopulateNeo4j(dbcon.Session, verbose=True)
# Out:
# create Disease node with name as Fin or tail rot
# Set props on Disease-Fin or tail rot:
# environment - ALL
# affectfish - nan
# cause - The most common causes of fin rot are poor water quality and improperly-low water temperature.
# Overcrowding the tank, feeding outdated food, overfeeding the fish, and moving or handling, bullying from other fish can also cause stress that leads to fin rot.
# treatment - Several antibiotics are effective in treating fin rot, but the root cause must be addressed to ensure the disease doesnât return.
# Treatment should include a water change and careful examination of the aquarium conditions.
# If there is food debris, vacuum the gravel and take care to avoid overfeeding in the future.
# Start putting dates on your fish food, as it loses the vitamin content fairly quickly after the food container is opened.
# Feeding your fish fresh, high-quality food in smaller quantities is far better than frequent, large feedings of stale foods.
# Check the pH and temperature of the water, and make sure it is appropriate for your fish species.
#  Be sure there is no chlorine, ammonia, or nitrite in the water and the nitrate is under 40 ppm (mg/L).
# Once the root cause is corrected, antibiotics will usually cure the disease itself.
# Treatment with a drug that is effective against gram-negative organisms is recommended.
# Consult with a veterinarian who treats fish (there are many Certified Aquatic Veterinarians now) to get the appropriate antibiotics for your fish.
# vet_advised - True
# create AKA node with name as Aeromonas salmonicida
# create Fin or tail rot -AKA-> Aeromonas salmonicida
# create Symptom node with name as Fins or tail edges appear white
# create Fin or tail rot -hasSymptom-> Fins or tail edges appear white
# create Fins or tail edges appear white -isDetectedIn-> Fin or tail rot
# create Symptom node with name as Frayed and ragged fins
# create Fin or tail rot -hasSymptom-> Frayed and ragged fins
# create Frayed and ragged fins -isDetectedIn-> Fin or tail rot
# create Symptom node with name as Frayed Tail
# create Fin or tail rot -hasSymptom-> Frayed Tail
# create Frayed Tail -isDetectedIn-> Fin or tail rot
# create Symptom node with name as Swimming difficulty
# create Fin or tail rot -hasSymptom-> Swimming difficulty
# create Swimming difficulty -isDetectedIn-> Fin or tail rot
# create Symptom node with name as Loss of appetite
# create Fin or tail rot -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Fin or tail rot
# create Symptom node with name as Settle Bottom of Tank
# create Fin or tail rot -hasSymptom-> Settle Bottom of Tank
# create Settle Bottom of Tank -isDetectedIn-> Fin or tail rot
# create Medication node with name as Antibiotics for Gram-Negative Organisms
# create Fin or tail rot -useMedication-> Antibiotics for Gram-Negative Organisms
# create Antibiotics for Gram-Negative Organisms -knownTreatment-> Fin or tail rot
# create Disease node with name as Cloudy Eye
# Set props on Disease-Cloudy Eye:
# environment - ALL
# affectfish - nan
# cause - A number of factors can cause eye cloud in fish.
# These lesions may result from poor water quality, including gas imbalances (causing exophthalmos), toxicants (cataract, hyperemia, keratitis and retinitis), nutritional deficiencies (cataract), parasite such as catarrhiniosis which can cause injury to the eye.
# treatment - Change the filter (or clean it) and get rid of any debris on top or near where they swim around most often.
# Check for medications that may have caused some bacteria build up at one end so as not to interfere with whatever is causing their eyesight problem next time these symptoms arise again.
# Finally, if that doesnât help, you will need to cure your fish of bacterial infection using a strong antibiotic.
# You can ask your vet for a prescription or recommended brand, and then administer it according to the guidelines listed on the medication
# vet_advised - True
# create Symptom node with name as Cloudy white or greyish eyes
# create Cloudy Eye -hasSymptom-> Cloudy white or greyish eyes
# create Cloudy white or greyish eyes -isDetectedIn-> Cloudy Eye
# create Symptom node with name as Loss of vision
# create Cloudy Eye -hasSymptom-> Loss of vision
# create Loss of vision -isDetectedIn-> Cloudy Eye
# create Symptom node with name as Show signs of distress
# create Cloudy Eye -hasSymptom-> Show signs of distress
# create Show signs of distress -isDetectedIn-> Cloudy Eye
# create Medication node with name as Strong Antibiotics
# create Cloudy Eye -useMedication-> Strong Antibiotics
# create Strong Antibiotics -knownTreatment-> Cloudy Eye
# create Disease node with name as Columnaris
# Set props on Disease-Columnaris:
# environment - Freshwater
# affectfish - nan
# cause - Columnaris bacteria are commensal bacteria and occur naturally on healthy fish.
# Only when given a stressed out host or particularly nasty strain of bacteria, do the fish begin to show clinical signs.
# It commonly enters a healthy system when infected fish are added without proper quarantine.
# Columnaris can enter the fish through the gills, mouth, or via small wounds on the skin.
# The disease is highly contagious and may be spread through contaminated nets, specimen containers, and even food.
# For this reason, it is important to use sterile techniques to avoid contaminating other tanks.
# Prophylactic treatment of all other tanks is wise and is mandatory if they share a common filtration system.â
# It is critical to keep a close eye on your tank's temperature, since columnaris bacteria love warmer water (around 80F) and will cause problems faster than in cooler water.
# treatment - External infections should be treated with antibiotics, chemicals in the water or both.
# Copper sulfate, Acriflavine, Furan, and Terramycin may all be used in the water to treat columnaris.
# Terramycin has proven to be quite effective both as a bath, and when used to treat foods for internal infections.
# Salt may be added to the water (1 to 3 teaspoons per gallon of water) to reduce osmotic stress on fish from the damage to the fish's epithelium caused by the bacteria.
# Livebearers, in particular, will benefit from the addition of salt; however, use caution when treating catfish, as many are highly sensitive to salt.
# When in doubt, err on the side of caution when using salt.
# vet_advised - False
# create AKA node with name as Cotton Mouth
# create Columnaris -AKA-> Cotton Mouth
# create Symptom node with name as Frayed and ragged fins
# create Columnaris -hasSymptom-> Frayed and ragged fins
# create Frayed and ragged fins -isDetectedIn-> Columnaris
# create Symptom node with name as Skin Ulcer
# create Columnaris -hasSymptom-> Skin Ulcer
# create Skin Ulcer -isDetectedIn-> Columnaris
# create Symptom node with name as Skin Peeling
# create Columnaris -hasSymptom-> Skin Peeling
# create Skin Peeling -isDetectedIn-> Columnaris
# create Symptom node with name as Greyish or White or cloudy patches on the gill
# create Columnaris -hasSymptom-> Greyish or White or cloudy patches on the gill
# create Greyish or White or cloudy patches on the gill -isDetectedIn-> Columnaris
# create Symptom node with name as Mucus on the gills, head, and dorsal regions
# create Columnaris -hasSymptom-> Mucus on the gills, head, and dorsal regions
# create Mucus on the gills, head, and dorsal regions -isDetectedIn-> Columnaris
# create Symptom node with name as Light or dark brown gills
# create Columnaris -hasSymptom-> Light or dark brown gills
# create Light or dark brown gills -isDetectedIn-> Columnaris
# create Symptom node with name as Breathing rapidly
# create Columnaris -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> Columnaris
# create Symptom node with name as Loss of appetite
# create Columnaris -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Columnaris
# create Symptom node with name as Greyish or White or cloudy patches on the mouth
# create Columnaris -hasSymptom-> Greyish or White or cloudy patches on the mouth
# create Greyish or White or cloudy patches on the mouth -isDetectedIn-> Columnaris
# create Symptom node with name as Cotton wool like growth
# create Columnaris -hasSymptom-> Cotton wool like growth
# create Cotton wool like growth -isDetectedIn-> Columnaris
# create Medication node with name as Copper Sulfate
# create Columnaris -useMedication-> Copper Sulfate
# create Copper Sulfate -knownTreatment-> Columnaris
# create Medication node with name as Acriflavine
# create Columnaris -useMedication-> Acriflavine
# create Acriflavine -knownTreatment-> Columnaris
# create Medication node with name as Furan
# create Columnaris -useMedication-> Furan
# create Furan -knownTreatment-> Columnaris
# create Medication node with name as Terramycin
# create Columnaris -useMedication-> Terramycin
# create Terramycin -knownTreatment-> Columnaris
# create Medication node with name as Salt
# create Columnaris -useMedication-> Salt
# create Salt -knownTreatment-> Columnaris
# create Disease node with name as Dropsy
# Set props on Disease-Dropsy:
# environment - ALL
# affectfish - nan
# cause - Dropsy in fish is actually a cluster of symptoms caused by an infection from bacteria commonly present in all aquariums.
# Consequently, any fish may be exposed to the dropsy-causing bacteria, but healthy fish rarely fall prey to the disease.
# Fish are only susceptible when their immune system has been compromised by some other stress factor, such as:
# Poor water quality
# Ammonia or nitrite spikes
# A large drop in water temperature
# Stress from transportation
# Improper nutrition
# Aggressive tankmates
# Other diseases
# The agent that causes the symptoms of dropsy is usually the very common Aeromonas bacteria, one of several gram-negative bacteria present in most aquarium habitats.
# The bacteria will only lead to serious infection in a fish that already has a compromised immune system.
# treatment - The infection-causing dropsy is not easily cured.
# Some experts recommend that all affected fish be euthanized to prevent the spread of the infection to healthy fish.
# Also, when combined with popeye, the prognosis is bleak.
# However, if the infection is detected early and the fish are isolated for proper treatment, it is possible to save the affected fish.
# Treatment is geared toward correcting the underlying problem and providing supportive care to the sick fish in a "hospital tank."
# Salt should be added to the hospital tank, again at the ratio of 1 teaspoon per gallon of water.
# Low levels of salt in the water aid in the osmotic balance of the fish by making the water salinity closer to the fish's blood salinity.
# That helps the fish get rid of excess water accumulating in the body, causing dropsy.
# Provide the ill fish with a variety of fresh, high-quality food.
# Antibiotics should be used if the fish does not immediately respond.
# A broad-spectrum antibiotic specifically formulated for gram-negative bacteria is recommended, such as Maracyn-Two following the manufacturer's directions for duration and dosage.
# vet_advised - False
# create Symptom node with name as Bloated abdomen or belly
# create Dropsy -hasSymptom-> Bloated abdomen or belly
# create Bloated abdomen or belly -isDetectedIn-> Dropsy
# create Symptom node with name as Scales stick out
# create Dropsy -hasSymptom-> Scales stick out
# create Scales stick out -isDetectedIn-> Dropsy
# create Symptom node with name as Eyes protruding
# create Dropsy -hasSymptom-> Eyes protruding
# create Eyes protruding -isDetectedIn-> Dropsy
# create Symptom node with name as Lethargic behavior
# create Dropsy -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Dropsy
# create Symptom node with name as Loss of appetite
# create Dropsy -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Dropsy
# create Symptom node with name as Rapid gill movement
# create Dropsy -hasSymptom-> Rapid gill movement
# create Rapid gill movement -isDetectedIn-> Dropsy
# create Medication node with name as Salt
# create Dropsy -useMedication-> Salt
# create Salt -knownTreatment-> Dropsy
# create Medication node with name as Antibiotics for Gram-Negative Bacteria
# create Dropsy -useMedication-> Antibiotics for Gram-Negative Bacteria
# create Antibiotics for Gram-Negative Bacteria -knownTreatment-> Dropsy
# create Disease node with name as Fish TuberculosisÂ
# Set props on Disease-Fish TuberculosisÂ :
# environment - ALL
# affectfish - nan
# cause - Addition of non-symptomatic (carrier) fish
# Addition of infected plants or other biological materials
# Transferred on owners hands without proper sanitation
# Since many Mycobaterium spp. are common in the environment, not taking the time to properly wash your hands before handling aquarium or fish may transfer bacteria.
# treatment - There is no effective treatment of fish tuberculosis other than supportive care.
# Some fish can live for a long time with an infection and show no outward clinical signs of disease.
# You may see a long-term pattern of random deaths with no links to other diseases, fish additions, diet or other environmental causes, such as water quality.
# If any fish test positive for fish tuberculosis in your system, it is assumed all fish are infected.
# Once a fish in your system has tested positive, you may keep the tank as a closed system, no new fish in or out, and be sure to take proper biosecurity precautions, such as gloves, or elect to depopulate and disinfect your system.
# Depopulation is recommended in immune-compromised environments.
# vet_advised - False
# create AKA node with name as Mycobacterium spp
# create Fish TuberculosisÂ  -AKA-> Mycobacterium spp
# create Symptom node with name as Lethargic behavior
# create Fish TuberculosisÂ  -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Hollowed belly
# create Fish TuberculosisÂ  -hasSymptom-> Hollowed belly
# create Hollowed belly -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Turn pale
# create Fish TuberculosisÂ  -hasSymptom-> Turn pale
# create Turn pale -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Skin Ulcer
# create Fish TuberculosisÂ  -hasSymptom-> Skin Ulcer
# create Skin Ulcer -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Frayed and ragged fins
# create Fish TuberculosisÂ  -hasSymptom-> Frayed and ragged fins
# create Frayed and ragged fins -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Fin and scale loss
# create Fish TuberculosisÂ  -hasSymptom-> Fin and scale loss
# create Fin and scale loss -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Yellowish or darker nodules on eyes or body
# create Fish TuberculosisÂ  -hasSymptom-> Yellowish or darker nodules on eyes or body
# create Yellowish or darker nodules on eyes or body -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Loss of appetite
# create Fish TuberculosisÂ  -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Fish TuberculosisÂ
# create Symptom node with name as Hiding behavior
# create Fish TuberculosisÂ  -hasSymptom-> Hiding behavior
# create Hiding behavior -isDetectedIn-> Fish TuberculosisÂ
# create Disease node with name as Viral Hemorrhagic SepticemiaÂ
# Set props on Disease-Viral Hemorrhagic SepticemiaÂ :
# environment - ALL
# affectfish - nan
# cause - Viral hemorrhagic septicemia (VHS) is a deadly infectious fish disease caused by Viral hemorrhagic septicemia virus.
# It afflicts over 50 species of freshwater and marine fish.
# Different strains of the virus occur in different regions, and affect different species.
# VHSV can be spread from fish to fish through water transfer, as well as through contaminated eggs, and fish from infected waters.
# Survivors of the disease can become lifelong carriers of the virus, contaminating water with urine, sperm, and ovarian fluids.
# treatment - As with many viral diseases of fish, there is no specific treatment or cure for VHS.
# The bacteria variant, bacterial hemorrhagic septicemia, can be treated with levamisole, metronidazole or praziquantel.
# Metronidazole and praziquantel are especially effective when used as food soaks.
# Antibiotics such as nitrofurazone or erythromycin may also help prevent secondary bacterial infections.
# A visit to the vet is advised for proper diagnosis.
# vet_advised - True
# create AKA node with name as Egtved virus
# create Viral Hemorrhagic SepticemiaÂ  -AKA-> Egtved virus
# create Symptom node with name as Bright red streaks on fins
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Bright red streaks on fins
# create Bright red streaks on fins -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Patchy or darker body
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Patchy or darker body
# create Patchy or darker body -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Eyes protruding
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Eyes protruding
# create Eyes protruding -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Bloated abdomen or belly
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Bloated abdomen or belly
# create Bloated abdomen or belly -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Signs of bleeding
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Signs of bleeding
# create Signs of bleeding -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Breathing rapidly
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Gasping at the surface
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Gasping at the surface
# create Gasping at the surface -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Erratic swimming
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Erratic swimming
# create Erratic swimming -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Symptom node with name as Pale gill
# create Viral Hemorrhagic SepticemiaÂ  -hasSymptom-> Pale gill
# create Pale gill -isDetectedIn-> Viral Hemorrhagic SepticemiaÂ
# create Medication node with name as Levamisole
# create Viral Hemorrhagic SepticemiaÂ  -useMedication-> Levamisole
# create Levamisole -knownTreatment-> Viral Hemorrhagic SepticemiaÂ
# create Medication node with name as Metronidazole
# create Viral Hemorrhagic SepticemiaÂ  -useMedication-> Metronidazole
# create Metronidazole -knownTreatment-> Viral Hemorrhagic SepticemiaÂ
# create Medication node with name as Praziquantel
# create Viral Hemorrhagic SepticemiaÂ  -useMedication-> Praziquantel
# create Praziquantel -knownTreatment-> Viral Hemorrhagic SepticemiaÂ
# create Medication node with name as Nitrofurazone (Antibiotics)
# create Viral Hemorrhagic SepticemiaÂ  -useMedication-> Nitrofurazone (Antibiotics)
# create Nitrofurazone (Antibiotics) -knownTreatment-> Viral Hemorrhagic SepticemiaÂ
# create Medication node with name as Erythromycin (Antibiotics)
# create Viral Hemorrhagic SepticemiaÂ  -useMedication-> Erythromycin (Antibiotics)
# create Erythromycin (Antibiotics) -knownTreatment-> Viral Hemorrhagic SepticemiaÂ
# create Disease node with name as Freshwater Ich
# Set props on Disease-Freshwater Ich:
# environment - Freshwater
# affectfish - nan
# cause - The most common cause of Ich is failure to quarantine a new fish addition to the aquarium.
# Additional causes may include:
# Using infected equipment between tanks without proper sanitation
# Transferring infected filter media or dÃ©cor between tanks
# Moving infected water between systems
# treatment - Have a veterinarian examine your sick fish to make a correct diagnosis.
# There are other things on fish that can look remarkably similar to white spot disease that will require different treatment.
# Once a diagnosis is confirmed, there are treatment options available for prescription through your aquatic veterinarian and fish store.
# Monitoring and maintaining your water temperature is critical to ensure the parasite is completely eliminated from your system.
# Many over-the-counter "treatments" do not take this into account and if not properly used can severely hurt your fish in addition to not completely treating the Ich.
# Many online forums will recommend manipulating your tank temperature to speed up or immobilize Ich.
# Unfortunately, in doing so, you will stress out your fish and make them more susceptible to death from secondary causes.
# vet_advised - True
# create AKA node with name as White Spot
# create Freshwater Ich -AKA-> White Spot
# create Symptom node with name as White spots on the body and gills
# create Freshwater Ich -hasSymptom-> White spots on the body and gills
# create White spots on the body and gills -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Clamped fins
# create Freshwater Ich -hasSymptom-> Clamped fins
# create Clamped fins -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Lethargic behavior
# create Freshwater Ich -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Breathing rapidly
# create Freshwater Ich -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Loss of appetite
# create Freshwater Ich -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Freshwater Ich -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Rapid gill movement
# create Freshwater Ich -hasSymptom-> Rapid gill movement
# create Rapid gill movement -isDetectedIn-> Freshwater Ich
# create Symptom node with name as Settle Bottom of Tank
# create Freshwater Ich -hasSymptom-> Settle Bottom of Tank
# create Settle Bottom of Tank -isDetectedIn-> Freshwater Ich
# create Disease node with name as Popeye
# Set props on Disease-Popeye:
# environment - ALL
# affectfish - nan
# cause - Most commonly, fish popeye is caused by an injury, an infection, or poor water conditions in the aquarium.
# If only one eye is affected (unilateral), it is likely that the condition is caused by an injury rather than a problem with the water chemistry.
# This is particularly true if only one fish in a community tank is exhibiting popeye.
# A swollen eye can be the outcome of a fight with another fish, or your fish could have scraped its eye against an abrasive object in the tank.
# If this happens, look for damage to the eyeâa dead giveaway that exophthalmia is the result of an injury.
# In most injuries, the protruding eye will eventually recede as it heals.
# However, the fish should be monitored closely, as infection can ensue, causing the fish to lose sight in the affected eye.
# Another cause of popeye is an infection.
# This is most likely seen in both eyes.
# Infection may be caused by a variety of organisms, including bacteria, fungi, and parasites.
# If the fish suffers from both popeye and dropsy (edema of the belly), the prognosis is bleak.
# Internal problems, such as kidney failure or a metabolic issue can result in fluid build-up, making it extremely hard to treat your fish.
# Poor water conditions can also contribute to popeye and fish that are sensitive will be affected first.
# If one or more fish in your tank presents with popeye, test your water to determine if something is amiss with its chemistry.
# Also consider supersaturation of gas in the water, which can be seen as tiny bubbles on the sides of the aquarium and even in the fish's skin.
# This can cause gas to accumulate in the eyes and make them swell
# treatment - Treatment for popeye will depend upon the underlying cause.
# If the eye has been injured, it will typically heal on its own, as long as the fish does not develop a secondary infection or become stressed.
# You can help the fish recover by performing palliative care using aquarium salt while the eye heals (unless contraindicated).
# This helps to relieve the swelling.
# You should also remove any tank decorations that might contribute to further injuries, such as rough or sharp rocks, pointed plants, and decorative items with rough or pointed edges.
#
# Regular water changes and the monitoring of water chemistry are also recommended throughout the recovery time, as poor water condition is a common cause of popeye, as well as other fish ailments.
# If water tests indicate a problemâa drifting pH or elevated ammonia or nitriteâcorrect it promptly to avoid additional stress
#
# Any fish clearly suffering from a bacterial infection should be moved to a quarantine tank to avoid infecting other fish.
# Treat this fish with a broad-spectrum antibiotic recommended by your pet supplier or veterinarian to resolve the infection.
# If more than one fish is infected, it may be necessary to treat the main tank with antibiotics, as well.
# And all fish should be fed high-quality food to support healthy immune systems.
# vet_advised - True
# create AKA node with name as Exophthalmia
# create Popeye -AKA-> Exophthalmia
# create Symptom node with name as Eyes protruding
# create Popeye -hasSymptom-> Eyes protruding
# create Eyes protruding -isDetectedIn-> Popeye
# create Symptom node with name as Cloudy white or greyish eyes
# create Popeye -hasSymptom-> Cloudy white or greyish eyes
# create Cloudy white or greyish eyes -isDetectedIn-> Popeye
# create Symptom node with name as Bloodstained eye
# create Popeye -hasSymptom-> Bloodstained eye
# create Bloodstained eye -isDetectedIn-> Popeye
# create Symptom node with name as Ruptured eye
# create Popeye -hasSymptom-> Ruptured eye
# create Ruptured eye -isDetectedIn-> Popeye
# create Symptom node with name as Loss of vision
# create Popeye -hasSymptom-> Loss of vision
# create Loss of vision -isDetectedIn-> Popeye
# create Symptom node with name as Lethargic behavior
# create Popeye -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Popeye
# create Medication node with name as Salt
# create Popeye -useMedication-> Salt
# create Salt -knownTreatment-> Popeye
# create Medication node with name as Antibiotics
# create Popeye -useMedication-> Antibiotics
# create Antibiotics -knownTreatment-> Popeye
# create Disease node with name as Swim Bladder Disease
# Set props on Disease-Swim Bladder Disease:
# environment - ALL
# affectfish - nan
# cause - This disorder can be caused by many issues, spanning from environment to feeding problems, including the following:
# Rapidly eating, overeating, constipation, or gulping air may occur with floating foods to cause an extended belly and displace the swim bladder.
# Eating freeze-dried or dry flake food that expands when it becomes wet can also lead to an enlarged stomach or intestinal tract.
# Other abdominal organs may become enlarged and affect the swim bladder.
# Cysts in the kidneys, fatty deposits in the liver, or egg binding in female fish can result in sufficient enlargement to affect the swim bladder.
# Low water temperature can slow the digestive process, which in turn can result in gastrointestinal tract enlargement that puts pressure on the swim bladder.
# Parasites or bacterial infections can inflame the swim bladder as well.
# Occasionally a hard blow from striking an object in the tank, a fight, or fall can damage the swim bladder.
# Rarely fish are born with birth defects that affect the swim bladder, but in these cases, symptoms are usually present at an early age.
# treatment - Treatment involves water maintenance, feeding changes, and possible antibiotics.
# Let the fish fast: If an enlarged stomach or intestine is thought to be the cause of a swim bladder disorder, the first course of action is to not feed the fish for three days.
# Fix the water temperature: At the same time the fish is fasting, increase the water temperature to 78-80 degrees Fahrenheit and leave it there during treatment.
# Feed the fish peas: On the fourth day, feed the fish a cooked and skinned pea.
# Frozen peas are ideal for this, as they can be microwaved or boiled for a few seconds to thaw them, resulting in the proper consistency (not too soft but not too firm).
# Antibiotics: If an infection is thought to be the cause of a fish's swim bladder disorder, treatment with a broad-spectrum antibiotic may help, and for this, you'll need to visit your veterinarian.
# Other supportive treatments (regardless of the cause) can include the following:
# Keep the water especially clean and temperatures between 78 and 80 degrees Fahrenheit.
# Add a small amount of aquarium salt to the tank.
# Reduce the water level to make it easier for the fish to move around within the tank.
# Reduce water flow in tanks with a strong current.
# If the affected fish floats with part of its body constantly exposed to the air, applying a bit of Stress Coat water conditioner (which helps improve the fish's slime coat) can help avoid the development of sores and reddened spots.
# vet_advised - False
# create AKA node with name as Swim Bladder Disorder
# create Swim Bladder Disease -AKA-> Swim Bladder Disorder
# create Symptom node with name as Bloated abdomen or belly
# create Swim Bladder Disease -hasSymptom-> Bloated abdomen or belly
# create Bloated abdomen or belly -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Curved spine
# create Swim Bladder Disease -hasSymptom-> Curved spine
# create Curved spine -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Swimming difficulty
# create Swim Bladder Disease -hasSymptom-> Swimming difficulty
# create Swimming difficulty -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Upside down
# create Swim Bladder Disease -hasSymptom-> Upside down
# create Upside down -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Erratic swimming
# create Swim Bladder Disease -hasSymptom-> Erratic swimming
# create Erratic swimming -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Swimming with heavy head
# create Swim Bladder Disease -hasSymptom-> Swimming with heavy head
# create Swimming with heavy head -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Gasping at the surface
# create Swim Bladder Disease -hasSymptom-> Gasping at the surface
# create Gasping at the surface -isDetectedIn-> Swim Bladder Disease
# create Symptom node with name as Spend time on surface
# create Swim Bladder Disease -hasSymptom-> Spend time on surface
# create Spend time on surface -isDetectedIn-> Swim Bladder Disease
# create Medication node with name as Pea
# create Swim Bladder Disease -useMedication-> Pea
# create Pea -knownTreatment-> Swim Bladder Disease
# create Medication node with name as Salt
# create Swim Bladder Disease -useMedication-> Salt
# create Salt -knownTreatment-> Swim Bladder Disease
# create Medication node with name as Stress Coat Water Conditioner
# create Swim Bladder Disease -useMedication-> Stress Coat Water Conditioner
# create Stress Coat Water Conditioner -knownTreatment-> Swim Bladder Disease
# create Disease node with name as Freshwater velvet disease
# Set props on Disease-Freshwater velvet disease:
# environment - Freshwater
# affectfish - nan
# cause - In freshwater fish, Velvet is caused by either OÃ¶dinium pillularis or OÃ¶dinium limneticum.
# In marine fish, AmyloÃ¶dinium ocellatum causes the dreaded Coral Fish Disease.
# All three species have symptoms and life cycles similar to the well-known ciliated protozoan parasite, Ich.
# Like Ich, OÃ¶dinium may be present in most commercial aquariums, but only becomes a problem when the fish are stressed by poor quality water, changes in the water temperature, or being transported.
# treatment - Raise water temperature
# Dim lights for several days
# Add aquarium salt
# Treat with copper sulfate for ten days
# Discontinue carbon filtration during treatment
# Because Velvet is highly contagious and usually far advanced before being diagnosed, it is important to take steps to treat it as soon as possible.
# Treatment is targeted at the free-swimming stage (tomite) of the parasite.
# Copper sulfate is the treatment of choice.
# It should be used according to the manufacturerâs instructions for a full ten days to ensure that the parasite is completely eradicated.
# Atabrine (quinacrine hydrochloride) is another medication that can be used to treat Velvet.
# Because OÃ¶dinium is also photosynthetic, dimming the aquarium lights aids in eliminating the infestation. Increasing the water temperature to 82 degrees F will speed the life cycle of the parasite, making it faster to treat and infestation.
# Adding salt to the water (1 to 3 level teaspoons per gallon of water) will increase the mucus production of the fish to help deter the parasite and will reduce the osmotic stress in the water. Whenever adding any treatment to the aquarium water, activated carbon should be removed from the filter, as it will remove the medications from the water.
# vet_advised - False
# create AKA node with name as Gold Dust Disease
# create Freshwater velvet disease -AKA-> Gold Dust Disease
# create Symptom node with name as Fine yellow or light brown rust or film on skin
# create Freshwater velvet disease -hasSymptom-> Fine yellow or light brown rust or film on skin
# create Fine yellow or light brown rust or film on skin -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Skin Peeling
# create Freshwater velvet disease -hasSymptom-> Skin Peeling
# create Skin Peeling -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Clamped fins
# create Freshwater velvet disease -hasSymptom-> Clamped fins
# create Clamped fins -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Freshwater velvet disease -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Lethargic behavior
# create Freshwater velvet disease -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Breathing rapidly
# create Freshwater velvet disease -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Loss of appetite
# create Freshwater velvet disease -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Rapid gill movement
# create Freshwater velvet disease -hasSymptom-> Rapid gill movement
# create Rapid gill movement -isDetectedIn-> Freshwater velvet disease
# create Symptom node with name as Sudden Death
# create Freshwater velvet disease -hasSymptom-> Sudden Death
# create Sudden Death -isDetectedIn-> Freshwater velvet disease
# create Medication node with name as Salt
# create Freshwater velvet disease -useMedication-> Salt
# create Salt -knownTreatment-> Freshwater velvet disease
# create Medication node with name as Copper Sulfate
# create Freshwater velvet disease -useMedication-> Copper Sulfate
# create Copper Sulfate -knownTreatment-> Freshwater velvet disease
# create Medication node with name as Atabrine (Quinacrine Hydrochloride)
# create Freshwater velvet disease -useMedication-> Atabrine (Quinacrine Hydrochloride)
# create Atabrine (Quinacrine Hydrochloride) -knownTreatment-> Freshwater velvet disease
# create Disease node with name as Ammonia Poisoning
# Set props on Disease-Ammonia Poisoning:
# environment - ALL
# affectfish - nan
# cause - Ammonia can enter the tank through a number of different ways.
# The first way is through chemically treated tap water.
# Overfeeding and lack of cleaning add to a buildup of the bacteria that feed on this superfluous matter, resulting in an ammonia byproduct.
# Fish, themselves, also contribute to rising ammonia levels in tanks.
# When a fish eats food, the protein-building process that ensues (in order for them to grow larger) can produce a byproduct that enters their blood.
# This results in the seepage of ammonia through their gills and into the tank.
# treatment - If the ammonia level in your tank rises above 1 ppm (part per million) on a standard test kit, begin treatment immediately.
# Lowering the pH of the water will provide immediate relief, as will a 50 percent water change (be sure the water added is the same temperature as the aquarium).
# Several water changes within a short period of time may be required to drop the ammonia below 1 ppm.
# If the fish appear to be severely distressed, use a chemical pH control product to neutralize the ammonia.
# At this point, restrict feedings so that additional waste is reduced.
# In cases of very high ammonia levels, feedings need to be discontinued for several days.
# And obviously, no new fish should be added toâ the tank until both the ammonia and nitrite levels have fallen to zero.
# vet_advised - False
# create AKA node with name as Nitrite poisoning
# create Ammonia Poisoning -AKA-> Nitrite poisoning
# create Symptom node with name as Gasping at the surface
# create Ammonia Poisoning -hasSymptom-> Gasping at the surface
# create Gasping at the surface -isDetectedIn-> Ammonia Poisoning
# create Symptom node with name as Red or inflamed gill
# create Ammonia Poisoning -hasSymptom-> Red or inflamed gill
# create Red or inflamed gill -isDetectedIn-> Ammonia Poisoning
# create Medication node with name as Chemical pH Control Product
# create Ammonia Poisoning -useMedication-> Chemical pH Control Product
# create Chemical pH Control Product -knownTreatment-> Ammonia Poisoning
# create Disease node with name as Anchor Worms
# Set props on Disease-Anchor Worms:
# environment - Freshwater
# affectfish - nan
# cause - Anchor worms are macroscopic parasites, and can be seen by the naked eye.
# They are commonly found on koi and goldfish, but can be found on many freshwater fish species.
# The "worm" part extending out into the water is actually the female reproductive structures.
# Anchor worms occur when a new fish is added to an aquarium carrying juvenile anchor worms or a reproductively-active female in their skin.
# Skipping proper quarantine makes this parasite spread very rapidly.
# A single female anchor worm can produce hundreds of larvae every two weeks for up to 16 weeks in a 77F (25C) tank.
# Anchor worm juveniles can also be spread with the introduction of live plants.
# Aquatic plants can bring parasites like anchor worm into your aquarium if not properly quarantined.
# treatment - Anchor worms need to be removed correctly with a fish under sedation by your veterinarian.
# They will need to remove the entire parasite including the feeding end from under the fishâs skin.
# Depending on the level of infestation, sedation makes the process less stressful for the fish and allows the veterinarian to work more effectively without a squirming fish.
# Once the mature females have been removed, you may still have a microscopic problem: the juvenile stages.
# Over-the-counter "anchor worm" treatments are usually fairly effective against the juvenile stages, but they will not kill the adults.
# Another way of killing the free-swimming juvenile stage in the aquarium can be accomplished by removing your substrate and decor and running your water through a UV light.
# Treating anchor worms with organophosphates or diflubenzuron (dimilin) is effective, but needs to be undertaken with severe caution.
# Only use veterinary-approved products, keep them away from your other pets and children, and make sure to wear proper protection (i.e., gloves) when handling medications.
# The sites of adult attachment may also develop secondary bacterial infections.
# vet_advised - True
# create AKA node with name as Learnea spp
# create Anchor Worms -AKA-> Learnea spp
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Anchor Worms -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Anchor Worms
# create Symptom node with name as Red or inflamed scales
# create Anchor Worms -hasSymptom-> Red or inflamed scales
# create Red or inflamed scales -isDetectedIn-> Anchor Worms
# create Symptom node with name as Worm on body
# create Anchor Worms -hasSymptom-> Worm on body
# create Worm on body -isDetectedIn-> Anchor Worms
# create Symptom node with name as White greenish thread on body
# create Anchor Worms -hasSymptom-> White greenish thread on body
# create White greenish thread on body -isDetectedIn-> Anchor Worms
# create Medication node with name as Organophospates
# create Anchor Worms -useMedication-> Organophospates
# create Organophospates -knownTreatment-> Anchor Worms
# create Medication node with name as Diflubenzuron (Dimilin)
# create Anchor Worms -useMedication-> Diflubenzuron (Dimilin)
# create Diflubenzuron (Dimilin) -knownTreatment-> Anchor Worms
# create Disease node with name as CO2 Poisoning
# Set props on Disease-CO2 Poisoning:
# environment - ALL
# affectfish - nan
# cause - CO2 poisoning in fish can be caused by your CO2 reactor not working, or your plants not absorb CO2 due to the lights not working properly.
# treatment - The best way for you to treat CO2 poisoning in your fish is to use an air stone to agitate the surface. This causes the carbon dioxide to dissipate from the water. You can also adjust the rate of CO2 injection in your tank
# vet_advised - False
# create Symptom node with name as Breathing rapidly
# create CO2 Poisoning -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> CO2 Poisoning
# create Symptom node with name as Gasping at the surface
# create CO2 Poisoning -hasSymptom-> Gasping at the surface
# create Gasping at the surface -isDetectedIn-> CO2 Poisoning
# create Symptom node with name as Spend time on surface
# create CO2 Poisoning -hasSymptom-> Spend time on surface
# create Spend time on surface -isDetectedIn-> CO2 Poisoning
# create Disease node with name as Constipation
# Set props on Disease-Constipation:
# environment - ALL
# affectfish - nan
# cause - Fish in poor water quality have reduced appetites, refusing to eat when ammonia or nitrite rises.
# They then start to defecate their mucosal gut lining, leading to a milky, transparent poop and a constipation misdiagnosis.
# Temperature changes can cause bloating or blockages.
# The metabolisms of temperate fish are temperature driven, and as things cool their gut flora becomes less efficient, causing slow digestion.
# Internal tumours may press against the stomach or intestine, making it difficult to pass food through.
# Physical deformities, such as those in Balloon fish or goldfish, cause organs to be displaced or press against each other.
# Physical blockages occur in âgrubbingâ fish like goldfish, which have evolved to take in mouthfuls of sand, silt and mud.
# When placed into a tank with pea gravel, it may be swallowed, blocking the oesophagus.
# Physical blockages will require a vet, as it is likely youâll damage the fish trying to remove any obstruction.
# Incorrect diet is a major player. While many fish are extremely versatile in their eating habits, some foods simply do not suit some fish.
# Surface feeding plays a role, especially in goldfish. Goldfish are phyostomous, with a duct between the swim bladder and the oesophagus, for the purpose of getting air into the swim bladder.
# When goldfish feed on floating flakes or pellets, they are prone to swallowing down gulps of air with them. Once inside them, it not only interferes with digestion but also causes buoyancy issues.
# Stale or spoiled dry food is also a common issue.
# Lack of fibre is something that can cause constipation, but not with any particular regularity, and almost always only in tandem with offering improper diet or stale foods.
# treatment - One of the easiest ways to treat a constipated fish is to increase the amount of fiber in their diet and if necessary, deworm your fish.
# Another way to treat constipation is to dose your tank with Epson salt.
# Adding 1 to 3 teaspoons of salt per every 5 gallons of water will help.
# Epson salt will act as a muscle relaxant and help them be able to poop easier.
# vet_advised - False
# create Symptom node with name as Bloated abdomen or belly
# create Constipation -hasSymptom-> Bloated abdomen or belly
# create Bloated abdomen or belly -isDetectedIn-> Constipation
# create Symptom node with name as Swimming difficulty
# create Constipation -hasSymptom-> Swimming difficulty
# create Swimming difficulty -isDetectedIn-> Constipation
# create Symptom node with name as Erratic swimming
# create Constipation -hasSymptom-> Erratic swimming
# create Erratic swimming -isDetectedIn-> Constipation
# create Medication node with name as Epson Salt
# create Constipation -useMedication-> Epson Salt
# create Epson Salt -knownTreatment-> Constipation
# create Disease node with name as Fish Lice
# Set props on Disease-Fish Lice:
# environment - ALL
# affectfish - nan
# cause - Lice will enter your aquarium system undetected on an infested fish.
# If not properly quarantined, your fish and its low lice load will quickly spread throughout your system.
# Juvenile lice are microscopic and may not be noticed until they grow into adults.
# By holding new fish in quarantine, you will catch the adults before they spread and treatment will be significantly simpler.
# treatment - The most effective treatment against argulusosis is organophosphates, which usually are given as 2 or 3 doses at 1-wk intervals to kill emerging larvae and juveniles.
# Because adult fish lice continue to molt, they are susceptible to chitin synthesis inhibitors, such as the pesticide diflubenzuron (restricted use).
# Other compounds with a similar mechanism of action as that of diflubenzuron, such as lufenuron (0.13 mg/L; Program, Novartis Animal Health), have also been used with success.
# Oral enamectin is also effective.
# Other treatments of Argulus infestations include the use of common chemicals such as salt (NaCl), formaldehyde, potassium permanganate (2-5mg/l bath), and formalin
# Two applications of trichlorfon (0.25 ppm; Masoten, Dylox) 1 wk apart can be used as well.
# To eradicate Argulus, treatments such as trichlorfon (0.25 ppm for several hours) and emamectin benzoate have been used.
# It can take about 2 mo for Argulus to complete their life cycle; therefore, it is useful to rid tanks of egg contamination by using a disinfectant or by allowing the tanks to dry thoroughly for several days.
# Manual removal by vets can be help infected fish.
# vet_advised - True
# create AKA node with name as Argulus spp
# create Fish Lice -AKA-> Argulus spp
# create Symptom node with name as Dots on fish body or condensed at fin attachments
# create Fish Lice -hasSymptom-> Dots on fish body or condensed at fin attachments
# create Dots on fish body or condensed at fin attachments -isDetectedIn-> Fish Lice
# create Symptom node with name as Pale gill
# create Fish Lice -hasSymptom-> Pale gill
# create Pale gill -isDetectedIn-> Fish Lice
# create Symptom node with name as Skin Ulcer
# create Fish Lice -hasSymptom-> Skin Ulcer
# create Skin Ulcer -isDetectedIn-> Fish Lice
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Fish Lice -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Fish Lice
# create Symptom node with name as Pale skin color
# create Fish Lice -hasSymptom-> Pale skin color
# create Pale skin color -isDetectedIn-> Fish Lice
# create Symptom node with name as Lethargic behavior
# create Fish Lice -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Fish Lice
# create Symptom node with name as grey or green dots on skin
# create Fish Lice -hasSymptom-> grey or green dots on skin
# create grey or green dots on skin -isDetectedIn-> Fish Lice
# create Medication node with name as Organophosphates
# create Fish Lice -useMedication-> Organophosphates
# create Organophosphates -knownTreatment-> Fish Lice
# create Medication node with name as Lufenuron
# create Fish Lice -useMedication-> Lufenuron
# create Lufenuron -knownTreatment-> Fish Lice
# ...
#
# It has been demonstrated that goldfish, Carassius auratus, can carry Koi Herpes Virus2, so there is the potential that they can also carry carp pox. Goldfish will not show the symptoms of KHV when they are carriers, so it possible they can also carry carp pox between infected systems without showing clinical signs.
# treatment - Like all other herpes viruses, latent virions will bury deep into neural tissue, making them impossible to remove or treat.
# As for any species, herpes is for life.
# There is no treatment available at this time.
# Surgical removal of the plaques is not recommended since they will only grow back.
#
# You may alleviate the symptoms of carp pox by raising your water temperature.
# This will allow your koi to better combat the disease and may resolve symptoms entirely.
# This does not mean the virus is gone from your fish, as the lesions will return when the water cools again.
# vet_advised - False
# create AKA node with name as Koi Pox
# create Carp Pox -AKA-> Koi Pox
# create Symptom node with name as Waxy like spots on fin and body and head
# create Carp Pox -hasSymptom-> Waxy like spots on fin and body and head
# create Waxy like spots on fin and body and head -isDetectedIn-> Carp Pox
# create Symptom node with name as Thicken fins
# create Carp Pox -hasSymptom-> Thicken fins
# create Thicken fins -isDetectedIn-> Carp Pox
# create Symptom node with name as Skin Ulcer
# create Carp Pox -hasSymptom-> Skin Ulcer
# create Skin Ulcer -isDetectedIn-> Carp Pox
# create Disease node with name as Water Mold
# Set props on Disease-Water Mold:
# environment - ALL
# affectfish - nan
# cause - Of the water mold class Oomycetes, Saprolengniaceae is a family that contains many species commonly called "saprolegnia."
# There are so many different species that every freshwater fish is susceptible to some Saprolegnia species.
# Typically, water molds feed on dead organic materials and replicate by forming spores.
# These spores seed a substrate and float about, waiting for a bit of dead tissue to inhabit and grow into.
# Dead skin cells on fish with injuries or weakened immune systems make ideal hosts.
# Saprolegnia is an opportunistic pathogen that will likely infect fishes that are living poor water quality, wrong temperatures (eg tropical fishes in cold water) or are immunosuppressed by other infections or even high stress.
# treatment - It is imperative that Saprolegnia be properly diagnosed by an aquatic veterinarian prior to treatment.
# Water mold can look very similar to Columnaris bacteria and will require a completely different treatment.
# Your vet will do a skin mucus scrape or swab culture to determine the problematic pathogen.
# Since it is a water mold, it is not responsive to antibiotics.
# However, there may be a bacterial infection that caused the fish to be weak initially, allowing the Saprolegnia to grow on it.
# You may need to treat for both bacterial infections and the Saprolegnia fungus, using different medications.
# Severe infectious may require treatment specific to the water mold, using and antifungal medication in the water.
# vet_advised - True
# create AKA node with name as Saprolegnia
# create Water Mold -AKA-> Saprolegnia
# create Symptom node with name as White or greyish patch on skin
# create Water Mold -hasSymptom-> White or greyish patch on skin
# create White or greyish patch on skin -isDetectedIn-> Water Mold
# create Symptom node with name as Cotton like patchs on scale
# create Water Mold -hasSymptom-> Cotton like patchs on scale
# create Cotton like patchs on scale -isDetectedIn-> Water Mold
# create Symptom node with name as Sunken eyes
# create Water Mold -hasSymptom-> Sunken eyes
# create Sunken eyes -isDetectedIn-> Water Mold
# create Disease node with name as Saltwater Ich
# Set props on Disease-Saltwater Ich:
# environment - Saltwater
# affectfish - nan
# cause - Saltwater Ich is almost always present in the water of wild caught fish and are easily transmitted on anything wet.  This causes Saltwater Ich to exist in the holding tanks of fish wholesalers and distributors.  The parasites will then make their way to your local pet store and from there they will enter your home aquarium.
# treatment - Quarantine all fish, coral and invertebrates for at least 45 to 90 days or preventive medicine treatment could mitigate the risk of Saltwater Ich outbreaks.
# The two most proven and effective treatments for Marine Ich are Chloroquine Phosphate and Copper Sulfate based medications. CP or pharmaceutical grade Chloroquine Phosphate requires a prescription from a veterinarian, so this leads most hobbyists to use copper treatments. The CP that is available online from eBay and other websites is rarely medical grade and not worth the risk to your fish.
# Copper is a poison and has been compared to chemotherapy for fish. It is often deadly to fish at unregulated levels or if a fish is too weak when the treatment begins. Purchasing a reliable copper test kit is absolutely required if you intend to use any copper medications on your fish.
# Cupramine from Seachem is a very popular choice that contains ionic copper. Cupramine has the advantage of mixing much easier into the water than some other products. The Cupramine therapeutic level is 0.50 ppm and should only be read with the Seachem or Salifert copper test kit.
# Prime, Amguard or other ammonia binding products should be avoided while using Cupramine because they have been reported to increase the mortality rate of fish during treatment.
# Coppersafe is a much older liquid option that contains chelated copper with a therapeutic level between 1.5 â 2.0 ppm. The API test kit is recommended for this treatment and you are able to use ammonia binding products. However, there are reports that it less effective than some other options.
# Cuprion from Brightwell Aquatics is another ionic copper liquid-based treatment. The therapeutic level is 0.20 ppm. Seachem or Salifert copper test kit is recommended again for this product and ammonia binders should be avoided.
# Copper Power Blue is advertised as the safest treatment for Saltwater Ich. The therapeutic level between 1.5 â 2.0 ppm for Copper Power, but they claim 2.5ppm is also safe. The API test kit is recommended for monitoring this product.
# vet_advised - True
# create AKA node with name as White Spot
# create Saltwater Ich -AKA-> White Spot
# create Symptom node with name as Usually no signs in early stage
# create Saltwater Ich -hasSymptom-> Usually no signs in early stage
# create Usually no signs in early stage -isDetectedIn-> Saltwater Ich
# create Symptom node with name as White spots on the body and gills
# create Saltwater Ich -hasSymptom-> White spots on the body and gills
# create White spots on the body and gills -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Loss of appetite
# create Saltwater Ich -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Saltwater Ich -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Settle Bottom of Tank
# create Saltwater Ich -hasSymptom-> Settle Bottom of Tank
# create Settle Bottom of Tank -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Lethargic behavior
# create Saltwater Ich -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Erratic swimming
# create Saltwater Ich -hasSymptom-> Erratic swimming
# create Erratic swimming -isDetectedIn-> Saltwater Ich
# create Symptom node with name as Cloudy eyes
# create Saltwater Ich -hasSymptom-> Cloudy eyes
# create Cloudy eyes -isDetectedIn-> Saltwater Ich
# create Medication node with name as Chloroquine Phosphate
# create Saltwater Ich -useMedication-> Chloroquine Phosphate
# create Chloroquine Phosphate -knownTreatment-> Saltwater Ich
# create Medication node with name as Copper Sulfate
# create Saltwater Ich -useMedication-> Copper Sulfate
# create Copper Sulfate -knownTreatment-> Saltwater Ich
# create Medication node with name as Cupramine (Copper)
# create Saltwater Ich -useMedication-> Cupramine (Copper)
# create Cupramine (Copper) -knownTreatment-> Saltwater Ich
# create Medication node with name as Coppersafe (Copper)
# create Saltwater Ich -useMedication-> Coppersafe (Copper)
# create Coppersafe (Copper) -knownTreatment-> Saltwater Ich
# create Medication node with name as Cuprion (Copper)
# create Saltwater Ich -useMedication-> Cuprion (Copper)
# create Cuprion (Copper) -knownTreatment-> Saltwater Ich
# create Disease node with name as Marine Velvet Disease
# Set props on Disease-Marine Velvet Disease:
# environment - Saltwater
# affectfish - nan
# cause - In freshwater fish, Velvet is caused by either OÃ¶dinium pillularis or OÃ¶dinium limneticum.
# In marine fish, AmyloÃ¶dinium ocellatum causes the dreaded Coral Fish Disease.
# All three species have symptoms and life cycles similar to the well-known ciliated protozoan parasite, Ich.
# Like Ich, OÃ¶dinium may be present in most commercial aquariums, but only becomes a problem when the fish are stressed by poor quality water, changes in the water temperature, or being transported.
# treatment - Chloroquine phosphate is the treatment of choice for velvet, but copper also works if symptoms are caught early on.
# Tank transfer and hyposalinity do not work with velvet.
# A freshwater dip and/or chemical bath (discussed in more detail below) is recommended either before or during treatment, due to the severity of this disease; however these would only provide temporary relief and will not eradicate velvet.Tank fallow period of 6 weeks is advisable.Formalin â Cheap, effective and readily available; formalin can sometimes even be sourced from a vet or local pharmacy (37% Formaldehyde is what youâre looking for). However, the downsides are numerous: First, it can be very harsh â some fish cannot even survive in it the full 60 minutes. Formalin will quickly deplete oxygen from the water, so itâs important to aerate heavily for 30 minutes before and also during the bath treatment. The bath should be done in a large glass bowl/container or small aquarium, as plastic may absorb some of the medication and then leach it back out during future use. Finally, formalin is a known carcinogen, so precautions must be taken when handling it. Prevent your skin from coming into contact with it by wearing waterproof gloves, and protect your face by wearing a face mask and eye protection.
# Acriflavine â  It has a broad range of effect, being effective against both protozoans and bacterial infections. The latter gives it an advantage over using formalin, because all those tiny bite marks inflicted by velvet have the potential to get infected. You can also leave a fish in acriflavine longer than formalin, because it is not as harsh on the fish. Dosage varies by the product you are using, but for straight acriflavine (Acriflavine-MS) use 1 teaspoon per 5 gallons of water for a bath solution.
# Methylene Blue â May be added to the formalin bath only. It is a healing agent, useful for treating the tiny bite marks inflicted by velvet.
# Chloroquine phosphate/copper â While all of the above will remove the vast majority of velvet on a fish, some will inevitably survive. Within 4 days the remaining trophonts will drop off the fish, then encyst, and usually 48-96 hours later (although it can take up to 20+ days depending upon the strain) release dinospores (free swimmers) seeking to reinfect fish. The presence of CP or copper at therapeutic levels kills the dinospores, effectively shielding your fish from reinfection. It is important to note that CP/copper does not eradicate any other stage of velvet, just dinospores. It has zero impact on the parasites on the fish; they must âweather the stormâ until the trophonts fall off. This is why it is so important to do a freshwater dip and chemical bath beforehand, to reduce the number of parasites feeding on your fishâs body & gills.
# Wide spectrum antibiotic â Velvet does A LOT of damage to a fishâs skin & gills. The trophont sits on the skinâs surface and puts out small rhyzoids (root-like structures) into the skin of the host where it absorbs nutrients directly from the fishâs skin. With all those tiny wounds, the likelihood of infection is high. This is something I missed in my earlier experiments where the fish died. Therefore, I consider it prudent to preemptively treat withKanaplex and/or Furan-2 to ward off any potential bacterial infections which might arise.
# vet_advised - nan
# create AKA node with name as Coral Fish Disease
# create Marine Velvet Disease -AKA-> Coral Fish Disease
# create Symptom node with name as Initial stage like ich - tiny white spots mostly on fins and spreads fast to whole fish
# create Marine Velvet Disease -hasSymptom-> Initial stage like ich - tiny white spots mostly on fins and spreads fast to whole fish
# create Initial stage like ich - tiny white spots mostly on fins and spreads fast to whole fish -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Depending on fish color, spots will appear grey gold in certain angle and light conditions
# create Marine Velvet Disease -hasSymptom-> Depending on fish color, spots will appear grey gold in certain angle and light conditions
# create Depending on fish color, spots will appear grey gold in certain angle and light conditions -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Swimming into powerhead (air pump)
# create Marine Velvet Disease -hasSymptom-> Swimming into powerhead (air pump)
# create Swimming into powerhead (air pump) -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Hiding behavior
# create Marine Velvet Disease -hasSymptom-> Hiding behavior
# create Hiding behavior -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Lethargic behavior
# create Marine Velvet Disease -hasSymptom-> Lethargic behavior
# create Lethargic behavior -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Breathing rapidly
# create Marine Velvet Disease -hasSymptom-> Breathing rapidly
# create Breathing rapidly -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Loss of appetite
# create Marine Velvet Disease -hasSymptom-> Loss of appetite
# create Loss of appetite -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Erratic swimming
# create Marine Velvet Disease -hasSymptom-> Erratic swimming
# create Erratic swimming -isDetectedIn-> Marine Velvet Disease
# create Symptom node with name as Flashing or Rub against bottom or objects in the tank
# create Marine Velvet Disease -hasSymptom-> Flashing or Rub against bottom or objects in the tank
# create Flashing or Rub against bottom or objects in the tank -isDetectedIn-> Marine Velvet Disease
# create Medication node with name as Chloroquine Phosphate
# create Marine Velvet Disease -useMedication-> Chloroquine Phosphate
# create Chloroquine Phosphate -knownTreatment-> Marine Velvet Disease
# create Medication node with name as Formalin
# create Marine Velvet Disease -useMedication-> Formalin
# create Formalin -knownTreatment-> Marine Velvet Disease
# create Medication node with name as Acriflavine
# create Marine Velvet Disease -useMedication-> Acriflavine
# create Acriflavine -knownTreatment-> Marine Velvet Disease
# create Medication node with name as Methylene Blue
# create Marine Velvet Disease -useMedication-> Methylene Blue
# create Methylene Blue -knownTreatment-> Marine Velvet Disease
# create Medication node with name as Copper
# create Marine Velvet Disease -useMedication-> Copper
# create Copper -knownTreatment-> Marine Velvet Disease
# create Medication node with name as Antibiotics
# create Marine Velvet Disease -useMedication-> Antibiotics
# create Antibiotics -knownTreatment-> Marine Velvet Disease

# %% [markdown]
# ### Visualize created knowledge graph at: http://localhost:7474/browser/
#
# * Username: neo4j
#
# * Password: ai-user

# %%
dbcon = DataAccessLayer(username='neo4j',password='ai-user').CreateDBConnection
result2 = dbcon.GetAllNodeListOfType('Disease')
for resulti in result2:
    print("Disease Name: " + resulti.name)
    print(resulti.environment)
    for r in resulti.symptoms:
        print(r.name + " # " +str(r.id) +" === " + str(resulti.symptoms.relationship(r).weight) + str(resulti.symptoms.relationship(r).penalty))
    print("----------------------------")
# Out:
# Disease Name: Ammonia Poisoning
# ALL
# Red or inflamed gill # 4 === 1.0-0.2
# Gasping at the surface # 223 === 1.0-0.2
# ----------------------------
# Disease Name: Anchor Worms
# Freshwater
# White greenish thread on body # 10 === 1.0-0.2
# Worm on body # 9 === 1.0-0.2
# Red or inflamed scales # 8 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# ----------------------------
# Disease Name: CO2 Poisoning
# ALL
# Spend time on surface # 246 === 1.0-0.2
# Gasping at the surface # 223 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# ----------------------------
# Disease Name: Constipation
# ALL
# Erratic swimming # 224 === 1.0-0.2
# Swimming difficulty # 154 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# ----------------------------
# Disease Name: Fish Lice
# ALL
# grey or green dots on skin # 20 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Pale skin color # 19 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Pale gill # 225 === 1.0-0.2
# Dots on fish body or condensed at fin attachments # 18 === 1.0-0.2
# ----------------------------
# Disease Name: Flukes
# ALL
# Sudden Death # 0 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Pale skin color # 19 === 1.0-0.2
# Scale loss # 29 === 1.0-0.2
# ----------------------------
# Disease Name: Gill Mite
# ALL
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Clamped fins # 234 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Spend time on surface # 246 === 1.0-0.2
# Gasping at the surface # 223 === 1.0-0.2
# Gills not fully close # 32 === 1.0-0.2
# ----------------------------
# Disease Name: Hole in the head
# Saltwater
# White stringy faeces # 39 === 1.0-0.2
# Patchy or darker body # 221 === 1.0-0.2
# Pale gill # 225 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Ulcer on lateral line # 38 === 1.0-0.2
# Ulcer on head # 37 === 1.0-0.2
# ----------------------------
# Disease Name: Slime disease
# Freshwater
# Loss of appetite # 155 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# grey or white blue mucus # 43 === 1.0-0.2
# Thick skin mucus # 42 === 1.0-0.2
# ----------------------------
# Disease Name: Ichthyobodo
# ALL
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Clamped fins # 234 === 1.0-0.2
# Scale loss # 29 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Thick skin mucus # 42 === 1.0-0.2
# ----------------------------
# Disease Name: Polycystic Kidney Disease
# ALL
# Sudden Death # 0 === 1.0-0.2
# Rapid gill movement # 209 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Eyes protruding # 207 === 1.0-0.2
# Scales stick out # 206 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# ----------------------------
# Disease Name: Vibrosis
# ALL
# Frayed Tail # 153 === 1.0-0.2
# Inflamed anus # 50 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# Sudden Death # 0 === 1.0-0.2
# Scale loss # 29 === 1.0-0.2
# Signs of bleeding # 222 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# ----------------------------
# Disease Name: Lymphocystis
# ALL
# spots clumps together like cauliflower # 56 === 1.0-0.2
# White film on skin # 55 === 1.0-0.2
# Whte or pinkish bumps on skin or fins # 54 === 1.0-0.2
# Greyish or cream patches on skin and fins # 53 === 1.0-0.2
# ----------------------------
# Disease Name: Ichthyosporidium
# ALL
# Signs of bleeding # 222 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Hollowed belly # 213 === 1.0-0.2
# Swimming difficulty # 154 === 1.0-0.2
# ----------------------------
# Disease Name: Gill lice
# ALL
# Lethargic behavior # 208 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Red spots # 62 === 1.0-0.2
# Scale Loss # 61 === 1.0-0.2
# ----------------------------
# Disease Name: Nematoda
# ALL
# Lethargic behavior # 208 === 1.0-0.2
# Swimming difficulty # 154 === 1.0-0.2
# significant  weight loss # 67 === 1.0-0.2
# Worm seen at anus # 66 === 1.0-0.2
# Hollowed belly # 213 === 1.0-0.2
# ----------------------------
# Disease Name: Chilodonella
# Freshwater
# Late stage skin swollen # 73 === 1.0-0.2
# Light blue mucus layer on skin between head and dorsal fin # 72 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Clamped fins # 234 === 1.0-0.2
# Cloudy Skin # 71 === 1.0-0.2
# Thick skin mucus # 42 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# ----------------------------
# Disease Name: Carp Pox
# Freshwater
# Skin Ulcer # 165 === 1.0-0.2
# Thicken fins # 77 === 1.0-0.2
# Waxy like spots on fin and body and head # 76 === 1.0-0.2
# ----------------------------
# Disease Name: Water Mold
# ALL
# Sunken eyes # 82 === 1.0-0.2
# Cotton like patchs on scale # 81 === 1.0-0.2
# White or greyish patch on skin # 80 === 1.0-0.2
# ----------------------------
# Disease Name: Saltwater Ich
# Saltwater
# Cloudy eyes # 85 === 1.0-0.2
# Erratic swimming # 224 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Settle Bottom of Tank # 156 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# White spots on the body and gills # 233 === 1.0-0.2
# Usually no signs in early stage # 84 === 1.0-0.2
# ----------------------------
# Disease Name: Marine Velvet Disease
# Saltwater
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Erratic swimming # 224 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Hiding behavior # 217 === 1.0-0.2
# Swimming into powerhead (air pump) # 94 === 1.0-0.2
# Depending on fish color, spots will appear grey gold in certain angle and light conditions # 93 === 1.0-0.2
# Initial stage like ich - tiny white spots mostly on fins and spreads fast to whole fish # 92 === 1.0-0.2
# ----------------------------
# Disease Name: Fin or tail rot
# ALL
# Settle Bottom of Tank # 156 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Swimming difficulty # 154 === 1.0-0.2
# Frayed Tail # 153 === 1.0-0.2
# Frayed and ragged fins # 152 === 1.0-0.2
# Fins or tail edges appear white # 151 === 1.0-0.2
# ----------------------------
# Disease Name: Cloudy Eye
# ALL
# Show signs of distress # 161 === 1.0-0.2
# Loss of vision # 160 === 1.0-0.2
# Cloudy white or greyish eyes # 159 === 1.0-0.2
# ----------------------------
# Disease Name: Columnaris
# Freshwater
# Cotton wool like growth # 172 === 1.0-0.2
# Greyish or White or cloudy patches on the mouth # 171 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Light or dark brown gills # 169 === 1.0-0.2
# Mucus on the gills, head, and dorsal regions # 168 === 1.0-0.2
# Greyish or White or cloudy patches on the gill # 167 === 1.0-0.2
# Skin Peeling # 166 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Frayed and ragged fins # 152 === 1.0-0.2
# ----------------------------
# Disease Name: Dropsy
# ALL
# Rapid gill movement # 209 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Eyes protruding # 207 === 1.0-0.2
# Scales stick out # 206 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# ----------------------------
# Disease Name: Fish TuberculosisÂ
# ALL
# Hiding behavior # 217 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Yellowish or darker nodules on eyes or body # 216 === 1.0-0.2
# Fin and scale loss # 215 === 1.0-0.2
# Frayed and ragged fins # 152 === 1.0-0.2
# Skin Ulcer # 165 === 1.0-0.2
# Turn pale # 214 === 1.0-0.2
# Hollowed belly # 213 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# ----------------------------
# Disease Name: Viral Hemorrhagic SepticemiaÂ
# ALL
# Pale gill # 225 === 1.0-0.2
# Erratic swimming # 224 === 1.0-0.2
# Gasping at the surface # 223 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Signs of bleeding # 222 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# Eyes protruding # 207 === 1.0-0.2
# Patchy or darker body # 221 === 1.0-0.2
# Bright red streaks on fins # 220 === 1.0-0.2
# ----------------------------
# Disease Name: Freshwater Ich
# Freshwater
# Settle Bottom of Tank # 156 === 1.0-0.2
# Rapid gill movement # 209 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Clamped fins # 234 === 1.0-0.2
# White spots on the body and gills # 233 === 1.0-0.2
# ----------------------------
# Disease Name: Popeye
# ALL
# Lethargic behavior # 208 === 1.0-0.2
# Loss of vision # 160 === 1.0-0.2
# Ruptured eye # 239 === 1.0-0.2
# Bloodstained eye # 238 === 1.0-0.2
# Cloudy white or greyish eyes # 159 === 1.0-0.2
# Eyes protruding # 207 === 1.0-0.2
# ----------------------------
# Disease Name: Swim Bladder Disease
# ALL
# Spend time on surface # 246 === 1.0-0.2
# Gasping at the surface # 223 === 1.0-0.2
# Swimming with heavy head # 245 === 1.0-0.2
# Erratic swimming # 224 === 1.0-0.2
# Upside down # 244 === 1.0-0.2
# Swimming difficulty # 154 === 1.0-0.2
# Curved spine # 243 === 1.0-0.2
# Bloated abdomen or belly # 205 === 1.0-0.2
# ----------------------------
# Disease Name: Freshwater velvet disease
# Freshwater
# Sudden Death # 0 === 1.0-0.2
# Rapid gill movement # 209 === 1.0-0.2
# Loss of appetite # 155 === 1.0-0.2
# Breathing rapidly # 170 === 1.0-0.2
# Lethargic behavior # 208 === 1.0-0.2
# Flashing or Rub against bottom or objects in the tank # 235 === 1.0-0.2
# Clamped fins # 234 === 1.0-0.2
# Skin Peeling # 166 === 1.0-0.2
# Fine yellow or light brown rust or film on skin # 251 === 1.0-0.2
# ----------------------------

# %%
newCase = dbcon.CreateOrGetCaseNode('case1')
print(newCase.name + " # " + str(newCase.id))
# Out:
# case1 # 97

# %%
symptom1 = dbcon.GetOneSymptomNode("Bloodstained eye")
print(symptom1.id)
# Out:
# 238

# %%
dbcon = DataAccessLayer(username='neo4j',password='ai-user').CreateDBConnection
newCase = dbcon.CreateOrGetCaseNode('case1',None,True)
symptom1 = dbcon.GetOneSymptomNode("Bloodstained eye")
newCase = dbcon.UpdateSymptomToCase(newCase, symptom1, 0.5)
print(len(newCase.suspected_symptoms))
for r in newCase.suspected_symptoms:
    print(r.name + " # " +str(r.id) +" === " + str(newCase.suspected_symptoms.relationship(r).suspectedLevel))
# Out:
# 1
# Bloodstained eye # 238 === 0.5

# %%
for d in symptom1.diseases:
    dbcon.UpdateDiseaseToCase(newCase, d, 1/len(d.symptoms))
    print(d.name)
# Out:
# Popeye

# %%
symptom2 = dbcon.GetOneSymptomNode("Cloudy white or greyish eyes")
newCase = dbcon.UpdateSymptomToCase(newCase, symptom2)
for d in symptom2.diseases:
    confidence = 1/len(d.symptoms)
    rel = newCase.suspected_diseases.relationship(d)
    if rel:
        confidence += rel.confidence
    dbcon.UpdateDiseaseToCase(newCase, d, confidence)
    print(d.name)
# Out:
# Popeye
# Cloudy Eye
